# %% [markdown]
# ## BMI Calculator

# %%
name = input('Enter your name: ')

weight = int(input("Enter your weight in pounds: "))

height = int(input("Enter your weight in inches: "))

BMI = (weight * 703) / (height * height)

print('Your BMI is ' + str(BMI))

if BMI > 0:
    if BMI < 18.5:
        print(name + ', you are underweight.')
    elif BMI <=  24.9:
        print(name + ', you are Normal.')
    elif BMI <=  29.9:
        print(name + ', you are Overweight.')
    elif BMI <=  34.9:
        print(name + ', you are Obese.')
    elif BMI <=  39.9:
        print(name + ', you are Severely Obese.')
    elif BMI >=  40:
        print(name + ', you are Morbidly Obese.')
else:
    print('Please enter valid inputs')
# Out:
# Enter your name:  Billy
# Enter your weight in pounds:  140
# Enter your weight in inches:  67
# Your BMI is 21.92470483403876
# Billy, you are Normal.

# %% [markdown]
# ## ![image.png](attachment:f9edc59f-c7a7-4732-a253-d0d39094dc4f.png)
