# %% [markdown]
# ## INSTALL UNDETECTED-CHROMEDRIVER

# %%
# !pip install undetected-chromedriver

# %% [markdown]
# ## Import Libraries - Note the undetected_chromedriver

# %%
## Import Libraries

from bs4 import BeautifulSoup
import requests
import time
import undetected_chromedriver as uc
import datetime

import smtplib

# %% [markdown]
# ## Base code to connect to the URL and pull data

# %%
# Connect to website

url = 'https://www.amazon.com/Data-Science-Analytics-Funny-T-Shirt/dp/B07PB9XYH8'

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Referer": "https://www.google.com/"
}

page = requests.get(url, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id='productTitle').get_text().strip()

# Use class_ with an underscore and pass it as a keyword argument
price = soup2.find(id='corePriceDisplay_desktop_feature_div').get_text().strip()[1:6]

#price_element = soup2.find(id='corePriceDisplay_desktop_feature_div')
#if price_element:
#    price = price_element.get_text().strip()
    #To convert to a number for tracking: price_numeric = price.replace('$', '')
#print(f"Price: {price}")
#else:
#    print("Price not found.")

print(title)
print(price)

#title_element = soup.find(id='productTitle')
#if title_element:
#    title = title_element.get_text().strip()
#    print(f"Title: {title}")
#else:
#    print("Title not found. Amazon might be blocking you.")
# Out:
# Data Science Analytics Funny Got Data? T-Shirt T-Shirt
# 20.99

# %% [markdown]
# ## Add a timestamp for when the data is pulled - This could be moved up in the code

# %%
import datetime

today = datetime.date.today()

print(today)
# Out:
# 2026-01-28

# %% [markdown]
# ## Use this to setup your initial ingestion of data

# %%
import csv

header = ['Title', 'Price', 'Date']
data = [title, price, today]


### Commenting out the following lines so not to overwrite the csv file ###
#with open('AmazonWebScraperDataset.csv', 'w', newline = '', encoding='UTF8') as f:
    #writer = csv.writer(f)
    #writer.writerow(header)
    #writer.writerow(data)

# %% [markdown]
# ## Using pandas dataframes to check file without having to open it.

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\genesis\AmazonWebScraperDataset.csv")

print(df)
# Out:
#                                                Title  Price        Date
# 0  Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 1  Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 2  Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 3  Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28

# %% [markdown]
# ## Appending data to the initial load

# %%
# Now I'm going append data to the csv

with open('AmazonWebScraperDataset.csv', 'a+', newline = '', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %% [markdown]
# ## Full code to append to your csv based on the timer below

# %%
def check_price():
    url = 'https://www.amazon.com/Data-Science-Analytics-Funny-T-Shirt/dp/B07PB9XYH8'

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9",
        "Accept-Encoding": "gzip, deflate, br",
        "Referer": "https://www.google.com/"
    }

    page = requests.get(url, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup2.find(id='productTitle').get_text().strip()

    price = soup2.find(id='corePriceDisplay_desktop_feature_div').get_text().strip()[1:6]

    import datetime
    
    today = datetime.date.today()

    import csv
    
    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline = '', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

#    if(price < 18):
#        send_mail()

# %% [markdown]
# ## Automatically append new data based on the timer

# %%
while(True):
    check_price()
    time.sleep(5) #Time is in seconds
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 3
#       1 while(True):
#       2     check_price()
# ----> 3     time.sleep(5)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Just checking the csv file for updates

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\genesis\AmazonWebScraperDataset.csv")

print(df)
# Out:
#                                                 Title  Price        Date
# 0   Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 1   Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 2   Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 3   Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 4   Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 5   Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 6   Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 7   Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 8   Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 9   Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 10  Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28
# 11  Data Science Analytics Funny Got Data? T-Shirt...  20.99  2026-01-28

# %%
# If uou want to try sending yourself an email (just for fun) when a price hits below a certain level you can try it
# out with this script

#def send_mail():
#    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
#    server.ehlo()
    #server.starttls()
#    server.ehlo()
#    server.login('billy.lackey@gmail.com','xxxxxxxxxxxxxx')
    
#    subject = "The Shirt you want is below $15! Now is your chance to buy!"
#    body = "Alex, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data+analyst+tshirt&qid=1626655184&sr=8-3"
   
#    msg = f"Subject: {subject}\n\n{body}"
    
#    server.sendmail(
#        'billy.lackey@gmail.com',
#        msg
     
    )
